# %% [markdown]
# ### Assignment9 Submitted by____Tanuja Satish Dhope

# %%
1.Write a Python program to check if the given number is a Disarium Number?
2.Write a Python program to print all disarium numbers between 1 to 100?
3.Write a Python program to check if the given number is Happy Number?
4.Write a Python program to print all happy numbers between 1 and 100?
5.Write a Python program to determine whether the given number is a Harshad Number?
6.Write a Python program to print all pronic numbers between 1 and 100?

# %%
#1.Write a Python program to check if the given number is a Disarium Number?
### Disarium Numbers is a number  where in sum of its digits with power of their respective postion  is equal to the original number
### 1^1+3^2+5^2=135 like 89,175,518 etc.
def disarium_num_ck(number):
    temp=0
    for j in range(len(str(number))):
        temp+=int(str(number)[j])**(j+1)
    return temp==number
 
number=25

print("\n",number,"is a Disarium number?",disarium_num_ck(number))
number=89
print("\n",number,"is a Disarium number?",disarium_num_ck(number))
# Out:
#  25 is a Disarium number? False
#
#  89 is a Disarium number? True

# %%
#2.Write a Python program to print all disarium numbers between 1 to 100?
def disarium_num_ck(number):
    temp=0
    for j in range(len(str(number))):
        temp+=int(str(number)[j])**(j+1)
    return temp==number

print("Disarium numbers between 1 and 101 are:\n") 
for i in range(1,101):
    
    result=disarium_num_ck(i)
    if (result==True):
        print(i)
# Out:
# Disarium numbers between 1 and 101 are:
#
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 89

# %%
#3.Write a Python program to check if the given number is Happy Number?
## A happy number is a number which ends up as 1 when it is replaced by the sum of square of every digit in the number
def chk_happy_num(num1):
    rem=0
    num=0
    while(num1>0):
        rem=num1%10
        num+=rem**2
        num1 =num1//10
    return num 

number=25
happy_num=number
while(happy_num!=1 and happy_num!=4):
    happy_num=chk_happy_num(happy_num)
if (happy_num ==1):
    print(number,end=" ")

# %%
#4.Write a Python program to print all happy numbers between 1 and 100?

def chk_happy_num(num1):
    rem=0
    num=0
    while(num1>0):
        rem=num1%10
        num+=rem**2
        num1 =num1//10
    return num 


for i in range(1,100+1):
    happy_num=i
    while(happy_num!=1 and happy_num!=4):
        happy_num=chk_happy_num(happy_num)
    if (happy_num ==1):
        print(i,end=" ")
# Out:
# 1 7 10 13 19 23 28 31 32 44 49 68 70 79 82 86 91 94 97 100

# %%
5.Write a Python program to determine whether the given number is a Harshad Number?
## A number is said to be Harshad number if a given number is divisible by the sum of individual digits of that number
def chk_harshad_num(number):
    rem=0
    sum_digit=0
    while(number>0):
        rem=number%10
        sum_digit+=rem
        number//=10
    if number%sum_digit == 0:
        check=True
    else:
        check=False
    return check  
n=int(input("Enter the number"))

if (chk_harshad_num(n)):
    print("\n",n, " is Harshad Number")
# Out:
# Object `Number` not found.
# Enter the number45
#
#  45  is Harshad Number

# %%
##.Write a Python program to print all harshad numbers between 1 and 100?
def chk_harshad_num(number):
    rem=0
    sum_digit=0
    while(number>0):
        rem=number%10
        sum_digit+=rem
        number//=10
    if number%sum_digit == 0:
        check=True
    else:
        check=False
    return check  
for i in range(1,100+1):
    if (chk_harshad_num(i)):
        print("\n",i, " is Harshad Number")
# Out:
#  1  is Harshad Number
#
#  2  is Harshad Number
#
#  3  is Harshad Number
#
#  4  is Harshad Number
#
#  5  is Harshad Number
#
#  6  is Harshad Number
#
#  7  is Harshad Number
#
#  8  is Harshad Number
#
#  9  is Harshad Number
#
#  10  is Harshad Number
#
#  11  is Harshad Number
#
#  12  is Harshad Number
#
#  13  is Harshad Number
#
#  14  is Harshad Number
#
#  15  is Harshad Number
#
#  16  is Harshad Number
#
#  17  is Harshad Number
#
#  18  is Harshad Number
#
#  19  is Harshad Number
#
#  20  is Harshad Number
#
#  21  is Harshad Number
#
#  22  is Harshad Number
#
#  23  is Harshad Number
#
#  24  is Harshad Number
#
#  25  is Harshad Number
#
#  26  is Harshad Number
#
#  27  is Harshad Number
#
#  28  is Harshad Number
#
#  29  is Harshad Number
#
#  30  is Harshad Number
#
#  31  is Harshad Number
#
#  32  is Harshad Number
#
#  33  is Harshad Number
#
#  34  is Harshad Number
#
#  35  is Harshad Number
#
#  36  is Harshad Number
#
#  37  is Harshad Number
#
# ...

# %%
##6.Write a Python program to print all pronic numbers between 1 and 100?
## Pronic number is a number which is the product of two consecutive integers 
import math

# function to check
# Pronic Number
def checkPronic (y) :

    i = 0
    while ( i <= (int)(math.sqrt(y)) ) :
# Checking Pronic Number by multiplying consecutive numbers
        if ( y == i * (i + 1)) :
            return True
        i = i + 1

    return False

###

# Printing Pronic
# Numbers upto 100
j = 0
while (j <= 101 ) :
    if checkPronic(j) :
        print(j,end=" ")
    j+= 1
# Out:
# 0 2 6 12 20 30 42 56 72 90
